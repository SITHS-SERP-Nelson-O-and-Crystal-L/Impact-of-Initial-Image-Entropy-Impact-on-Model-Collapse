# %% [markdown]
# <a href="https://colab.research.google.com/github/SITHS-SERP-Nelson-O-and-Crystal-L/Impact-of-Initial-Image-Entropy-Impact-on-Model-Collapse/blob/main/SERP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q torch torchvision diffusers scipy clean-fid peft accelerate transformers bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 39.3 MB/s eta 0:00:00

# %%
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"
# lets pytorch access gpu memory locked up, which happens when working with tensors

# %%
# !hf auth login
# Out:
#   A new version of huggingface_hub is available: 1.11.0 → 1.15.0
#
#   Do you want to update now? [Y/n] (/usr/bin/python3 -m pip install -U huggingface_hub) n
#   Skipped. You can update later with: /usr/bin/python3 -m pip install -U huggingface_hub
#
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? [y/N]: n
# Token is valid (permission: read).
# The token `sd-3.5-med` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `sd-3.5-med`

# %%
# !pip install torchao --upgrade
import importlib, torchao
importlib.reload(torchao)
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 103.8 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.17.0
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# <module 'torchao' from '/usr/local/lib/python3.12/dist-packages/torchao/__init__.py'>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !rm -rf /content/caltech256

# !mkdir /content/caltech256

# !cp "/content/drive/MyDrive/caltech256.zip" /content/

# !unzip -q /content/caltech256.zip -d /content/caltech256

# we will remove old datasets in /content, recreate a new folder, copy zip from drive to colab, unzip into clean folder
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
from glob import glob
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

root = "/content/caltech256/256_ObjectCategories"
seed = 1110
rng = np.random.default_rng(seed)
train_paths = []
test_paths = []

categories = sorted(glob(os.path.join(root, "*")))

for cat_path in categories:
    images = sorted(glob(os.path.join(cat_path, "*.jpg")))
    rng.shuffle(images)
    train_paths.extend(images[:40])
    test_paths.extend(images[40:50])

# %%
import os
import json
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class CaltechSubset(Dataset):
    def __init__(self, data_list, transform=None):
        self.data_list = data_list
        self.transform = transform
    def __len__(self):
        return len(self.data_list)
    def __getitem__(self, idx):
        item = self.data_list[idx]
        path = item['path']
        img = Image.open(path).convert("RGB")
        folder = os.path.basename(os.path.dirname(path))
        label = int(folder.split('.')[0]) - 1
        if self.transform:
            img = self.transform(img)
        return img, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
def collate_fp16(batch):
    imgs, labels = zip(*batch)
    imgs = torch.stack(imgs).to(dtype=torch.float16)
    labels = torch.tensor(labels)
    return imgs, labels

# %%
"""
train_dataset = CaltechSubset(train_paths, transform=transform)
test_dataset = CaltechSubset(test_paths, transform=transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=2,
    num_workers=2,
    collate_fn=collate_fp16
)

test_loader = DataLoader(
    test_dataset,
    batch_size=2,
    num_workers=2,
    collate_fn=collate_fp16
)


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

train_dataset = CaltechSubset(train_paths, transform=transform)
test_dataset = CaltechSubset(test_paths, transform=transform)
train_dataset = CaltechSubset([{"path": p} for p in train_paths], transform=transform)
test_dataset  = CaltechSubset([{"path": p} for p in test_paths],  transform=transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=2,
    num_workers=2,
    collate_fn=collate_fp16
)

test_loader = DataLoader(
    test_dataset,
    batch_size=2,
    num_workers=2,
    collate_fn=collate_fp16
)"""

# %%
"""import numpy as np
from scipy.stats import entropy

def calculate_image_entropy(img_tensor):
    pixels = img_tensor.numpy().flatten()
    hist, _ = np.histogram(pixels, bins=256, density=True)
    return entropy(hist, base=2)

train_with_entropy = []
for i in range(len(train_dataset)):
    img, _ = train_dataset[i]
    score = calculate_image_entropy(img)
    train_with_entropy.append([train_paths[i], score])

test_with_entropy = []
for i in range(len(test_dataset)):
    img, _ = test_dataset[i]
    score = calculate_image_entropy(img)
    test_with_entropy.append([test_paths[i], score])"""

# %%
"""scores = [row[1] for row in train_with_entropy]
p33 = np.percentile(scores, 33.33)
p66 = np.percentile(scores, 66.66)

low_entropy_subset = [row for row in train_with_entropy if row[1] <= p33]
medium_entropy_subset = [row for row in train_with_entropy if p33 < row[1] <= p66]
high_entropy_subset = [row for row in train_with_entropy if row[1] > p66]"""
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_22834/2512562714.py in <cell line: 0>()
#       1 scores = [row[1] for row in train_with_entropy]
# ----> 2 p33 = np.percentile(scores, 33.33)
#       3 p66 = np.percentile(scores, 66.66)
#       4
#       5 low_entropy_subset = [row for row in train_with_entropy if row[1] <= p33]
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4285             raise ValueError("Weights must be non-negative.")
#    4286
# -> 4287     return _quantile_unchecked(
#    4288         a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4289
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4674                         weights=None):
#    4675     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4676     return _ureduce(a,
#    4677                     func=_quantile_ureduce_func,
#    4678                     q=q,
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py in _ureduce(a, func, keepdims, **kwargs)
#    3762                 kwargs['out'] = out[(Ellipsis, ) + index_out]
#    3763
# -> 3764     r = func(a, **kwargs)
#    3765
#    3766     if out is not None:
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4851             arr = a.copy()
#    4852             wgt = weights
# -> 4853     result = _quantile(arr,
#    4854                        quantiles=q,
#    4855                        axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py in _quantile(arr, quantiles, axis, method, out, weights)
#    4973                 axis=0)
#    4974             if supports_nans:
# -> 4975                 slices_having_nans = np.isnan(arr[-1, ...])
#    4976             else:
#    4977                 slices_having_nans = None
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
"""import json
import os

drive_folder = "/content/drive/MyDrive/Caltech256_Subsets"
os.makedirs(drive_folder, exist_ok=True)

low_data = [{"path": row[0], "entropy": float(row[1])} for row in low_entropy_subset]
med_data = [{"path": row[0], "entropy": float(row[1])} for row in medium_entropy_subset]
high_data = [{"path": row[0], "entropy": float(row[1])} for row in high_entropy_subset]
test_data = [{"path": row[0], "entropy": float(row[1])} for row in test_with_entropy]

files_to_save = {
    "train_low_entropy.json": low_data,
    "train_medium_entropy.json": med_data,
    "train_high_entropy.json": high_data,
    "test_full.json": test_data
}

for filename, data in files_to_save.items():
    file_path = os.path.join(drive_folder, filename)
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=4)"""
# Out:
# 'import json\nimport os\n\ndrive_folder = "/content/drive/MyDrive/Caltech256_Subsets"\nos.makedirs(drive_folder, exist_ok=True)\n\nlow_data = [{"path": row[0], "entropy": float(row[1])} for row in low_entropy_subset]\nmed_data = [{"path": row[0], "entropy": float(row[1])} for row in medium_entropy_subset]\nhigh_data = [{"path": row[0], "entropy": float(row[1])} for row in high_entropy_subset]\ntest_data = [{"path": row[0], "entropy": float(row[1])} for row in test_with_entropy]\n\nfiles_to_save = {\n    "train_low_entropy.json": low_data,\n    "train_medium_entropy.json": med_data,\n    "train_high_entropy.json": high_data,\n    "test_full.json": test_data\n}\n\nfor filename, data in files_to_save.items():\n    file_path = os.path.join(drive_folder, filename)\n    with open(file_path, \'w\') as f:\n        json.dump(data, f, indent=4)'

# %%
drive_folder = "/content/drive/MyDrive/Caltech256_Subsets"

def load_json(filename):
    with open(os.path.join(drive_folder, filename), 'r') as f:
        return json.load(f)

train_low_ds  = CaltechSubset(load_json("train_low_entropy.json"), transform=transform)
train_med_ds  = CaltechSubset(load_json("train_medium_entropy.json"), transform=transform)
train_high_ds = CaltechSubset(load_json("train_high_entropy.json"), transform=transform)
test_ds       = CaltechSubset(load_json("test_full.json"), transform=transform)

print(f"Low: {len(train_low_ds)}, med: {len(train_med_ds)}, high: {len(train_high_ds)}, test: {len(test_ds)}")
# Out:
# Low: 3426 | Med: 3426 | High: 3428 | Test: 2570

# %%
from huggingface_hub import hf_hub_download
import os

MODEL = "stabilityai/stable-diffusion-3.5-medium"
DEST  = "/content/sd35_medium"

files_to_download = [
    "model_index.json",
    "scheduler/scheduler_config.json",
    "tokenizer/tokenizer_config.json",
    "tokenizer/vocab.json",
    "tokenizer/merges.txt",
    "tokenizer/special_tokens_map.json",
    "tokenizer_2/tokenizer_config.json",
    "tokenizer_2/vocab.json",
    "tokenizer_2/merges.txt",
    "tokenizer_2/special_tokens_map.json",
    "text_encoder/config.json",
    "text_encoder/model.safetensors",
    "text_encoder_2/config.json",
    "text_encoder_2/model.safetensors",
    "vae/config.json",
    "vae/diffusion_pytorch_model.safetensors",
    "transformer/config.json",
    "transformer/diffusion_pytorch_model.safetensors",
]
for f in files_to_download:
    dest_path = os.path.join(DEST, f)
    if os.path.exists(dest_path):
        print(f"Skip since it already exists {f}")
        continue
    print(f"Downloading {f}")
    try:
        hf_hub_download(repo_id=MODEL, filename=f, local_dir=DEST)
    except Exception as e:
        print(f"error: {e}")
print("Done, syncing")
import shutil
shutil.copytree(DEST, "/content/drive/MyDrive/sd35_medium", dirs_exist_ok=True)
print("Drive synced")
# Out:
# Skip (it already exists): model_index.json
# Skip (it already exists): scheduler/scheduler_config.json
# Skip (it already exists): tokenizer/tokenizer_config.json
# Skip (it already exists): tokenizer/vocab.json
# Skip (it already exists): tokenizer/merges.txt
# Skip (it already exists): tokenizer/special_tokens_map.json
# Skip (it already exists): tokenizer_2/tokenizer_config.json
# Skip (it already exists): tokenizer_2/vocab.json
# Skip (it already exists): tokenizer_2/merges.txt
# Skip (it already exists): tokenizer_2/special_tokens_map.json
# Skip (it already exists): text_encoder/config.json
# Downloading text_encoder/model.safetensors...
# text_encoder/model.safetensors:   0%|          | 0.00/247M [00:00<?, ?B/s]
# Downloading text_encoder_2/config.json...
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading text_encoder_2/model.safetensors...
# text_encoder_2/model.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# Downloading vae/config.json...
# config.json:   0%|          | 0.00/809 [00:00<?, ?B/s]
# Downloading vae/diffusion_pytorch_model.safetensors...
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Downloading transformer/config.json...
# config.json:   0%|          | 0.00/524 [00:00<?, ?B/s]
# Downloading transformer/diffusion_pytorch_model.safetensors...
# transformer/diffusion_pytorch_model.safe(…):   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Done, syncing
# Drive synced

# %%
import shutil, os

# copy model from google drive to local storage for fast loading
src_path  = "/content/drive/MyDrive/sd35_medium"
dest_path = "/content/sd35_medium"

if not os.path.exists(dest_path):
    print("Copying model from Drive to local")
    shutil.copytree(src_path, dest_path)
    print("Done")
else:
    print("Model already exists locally")
# Out:
# Copying model from Drive to local
# Done

# %%
from diffusers import StableDiffusion3Img2ImgPipeline, SD3Transformer2DModel
from transformers import BitsAndBytesConfig
import torch

def load_fresh_model():
    print("Loading")

    # quantize only the transformer (biggest component)
    quant_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )

    transformer = SD3Transformer2DModel.from_pretrained(
        "/content/sd35_medium/transformer",
        quantization_config=quant_config,
        torch_dtype=torch.float16,
    )

    pipe = StableDiffusion3Img2ImgPipeline.from_pretrained(
        "/content/sd35_medium",
        transformer=transformer,
        local_files_only=True,
        text_encoder_3=None,
        tokenizer_3=None,
        torch_dtype=torch.float16,
    ).to('cuda')

    pipe.vae.to(dtype=torch.float32)
    pipe.vae.enable_slicing()
    pipe.vae.enable_tiling()
    print("Done")
    return pipe
# Out:
# Unable to import `torchao` Tensor objects. This may affect loading checkpoints serialized with `torchao`
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
from cleanfid import fid
import os
import numpy as np
from PIL import Image
import shutil

def compute_fid(generated_images, real_loader, sample_size_gen=1, sample_size_real=1):
    gen_imgs = generated_images[:sample_size_gen]
    real_imgs = []
    for imgs, _ in real_loader:
        real_imgs.extend(imgs)
        if len(real_imgs) >= sample_size_real:
            break
    real_imgs = real_imgs[:sample_size_real]

    os.makedirs("temp_real", exist_ok=True)
    os.makedirs("temp_gen", exist_ok=True)
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    for i, img in enumerate(real_imgs):
        img_denorm = (img.cpu().float() * std + mean).clamp(0, 1)
        img_np = (img_denorm.permute(1, 2, 0).numpy() * 255).astype(np.uint8)
        Image.fromarray(img_np).save(f"temp_real/{i:05d}.png")
    for i, img in enumerate(gen_imgs):
        img.save(f"temp_gen/{i:05d}.png")
    score = fid.compute_fid("temp_gen", "temp_real", device="cuda")

    shutil.rmtree("temp_real", ignore_errors=True)
    shutil.rmtree("temp_gen", ignore_errors=True)

    return score

# %%
# remove the leading number from each folder name to get text prompts.
import os, glob

CALTECH_ROOT = "/content/caltech256/256_ObjectCategories"

def build_category_prompts(root=CALTECH_ROOT):
    folders = sorted(glob.glob(os.path.join(root, "*")))
    prompts = []
    for f in folders:
        name = os.path.basename(f)  # names are like '002.american-flag'
        label = name.split('.', 1)[-1] # converts to 'american-flag'
        label = label.replace('-', ' ') # converts to 'american flag'
        prompts.append(label)
    return prompts # returns the properly formatted english category names

CATEGORY_PROMPTS = build_category_prompts()
print(f"Loaded {len(CATEGORY_PROMPTS)} category prompts")
print("Sample:", CATEGORY_PROMPTS[:5])

import random
from torch.utils.data import Dataset, ConcatDataset
from PIL import Image
from torchvision import transforms

# reusing the same transform already defined in Cell 7
syn_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

class SyntheticImageDataset(Dataset):
    # wraps a list of PIL images (synthetic outputs) as a Dataset
    def __init__(self, pil_images, transform=None):
        self.images = pil_images
        self.transform = transform
    def __len__(self):
        return len(self.images)
    def __getitem__(self, idx):
        img = self.images[idx].convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, -1   # -1 = synthetic, no real label needed

def build_mixed_loader(human_dataset, synthetic_pil_images, batch_size=1, seed=1110):
    """
    Combines 50% human images + 50% synthetic images (after gen 0) into one DataLoader
    Both halves are randomly sampled without replacement
    """
    rng = random.Random(seed)

    if len(synthetic_pil_images) == 0:
        print("gen 0 — using 100% human data.")
        return torch.utils.data.DataLoader(
            human_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fp16
        )

    # n = number, this figures out what size the datasets are
    n_human = len(human_dataset)
    n_syn   = len(synthetic_pil_images)
    half    = min(n_human, n_syn)   # take equal halves up to whichever is smaller

    # creates the human subset made from half the original
    human_indices = rng.sample(range(n_human), half)
    human_subset  = torch.utils.data.Subset(human_dataset, human_indices)

    # creates the synthetic subset made from half the original
    syn_sample = rng.sample(synthetic_pil_images, half)
    syn_ds     = SyntheticImageDataset(syn_sample, transform=syn_transform)

    mixed_ds = ConcatDataset([human_subset, syn_ds])
    print(f"Mixed loader: {half} human + {half} synthetic = {len(mixed_ds)} total images")

    return torch.utils.data.DataLoader(
        mixed_ds, batch_size=batch_size, shuffle=True,  collate_fn=collate_fp16
    )
# Out:
# Loaded 257 category prompts
# Sample: ['ak47', 'american flag', 'backpack', 'baseball bat', 'baseball glove']
# build_mixed_loader() ready

# %%
import torch
import torch.nn.functional as F
from peft import LoraConfig, get_peft_model

def finetune_lora(pipe, train_loader, epochs=1, lr=1e-4):
    if hasattr(pipe.transformer, "_hf_hook"):
        from accelerate.hooks import remove_hook_from_module
        remove_hook_from_module(pipe.transformer, recurse=True)

    lora_config = LoraConfig(
        r=2,
        lora_alpha=4,
        target_modules=["to_q", "to_k", "to_v"],
    )
    pipe.transformer = get_peft_model(pipe.transformer, lora_config)
    pipe.transformer.print_trainable_parameters()

    pipe.vae            = pipe.vae.to("cuda", dtype=torch.float32)
    pipe.text_encoder   = pipe.text_encoder.to("cuda", dtype=torch.float32)
    pipe.text_encoder_2 = pipe.text_encoder_2.to("cuda", dtype=torch.float32)
    pipe.transformer    = pipe.transformer.to("cuda", dtype=torch.float32)

    optimizer = torch.optim.AdamW(
        filter(lambda p: p.requires_grad, pipe.transformer.parameters()),
        lr=lr
    )

    scheduler = pipe.scheduler
    pipe.transformer.train()
    pipe.vae.eval()
    pipe.text_encoder.eval()
    pipe.text_encoder_2.eval()

    for epoch in range(epochs):
        epoch_loss = 0.0
        num_batches = 0

        for batch in train_loader:
            imgs, _ = batch
            imgs = imgs.to("cuda", dtype=torch.float32)

            with torch.no_grad(), torch.autocast("cuda", dtype=torch.float16):
                latents = pipe.vae.encode(imgs).latent_dist.sample()
                latents = latents * pipe.vae.config.scaling_factor
            latents = latents.to(dtype=torch.float16)

            bsz = latents.shape[0]
            timesteps = torch.randint(
                0, scheduler.config.num_train_timesteps,
                (bsz,), device="cuda"
            ).long()

            noise = torch.randn_like(latents)
            t = (timesteps.float() / scheduler.config.num_train_timesteps).view(-1, 1, 1, 1)
            noisy_latents = t * noise + (1 - t) * latents

            with torch.no_grad():
                prompt_embeds, negative_embeds, pooled, neg_pooled = \
                    pipe.encode_prompt(
                        prompt=[""] * bsz,
                        prompt_2=[""] * bsz,
                        prompt_3=[""] * bsz,
                        device="cuda",
                        num_images_per_prompt=1,
                        do_classifier_free_guidance=False,
                    )

            with torch.autocast("cuda", dtype=torch.float16):
                model_output = pipe.transformer(
                    hidden_states=noisy_latents,
                    timestep=timesteps,
                    encoder_hidden_states=prompt_embeds,
                    pooled_projections=pooled,
                    return_dict=False,
                )[0]

            velocity_target = noise - latents
            loss = F.mse_loss(model_output.float(), velocity_target.float())

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            epoch_loss += loss.item()
            num_batches += 1

        avg_loss = epoch_loss / max(num_batches, 1)


    pipe.transformer.eval()
    return pipe

# %%
import torch, time, random, os, json, zipfile, gc
import numpy as np
from PIL import Image

DRIVE_BASE            = "/content/drive/MyDrive/Caltech256_Subsets"
TOTAL_IMAGES_PER_GEN  = 250
TOTAL_TRAIN_IMAGES = TOTAL_IMAGES_PER_GEN * 2
BATCH_SIZE            = 1
NUM_INFERENCE_STEPS   = 10
STRENGTH              = 0.7
GUIDANCE_SCALE        = 7.0
DEVICE                = "cuda" if torch.cuda.is_available() else "cpu"
GENERATIONS           = 10
number_of_models      = 3
SEED                  = 1110
rng                   = random.Random(SEED)

dataset_labels = ["LOW", "MED", "HIGH"]
human_datasets = [train_low_ds,train_med_ds, train_high_ds]

# Checkpoint
def save_synthetic_to_drive(images, label, gen):
    zip_path = os.path.join(DRIVE_BASE, f"synthetic_{label}_gen{gen}.zip")
    with zipfile.ZipFile(zip_path, 'w') as zf:
        for i, img in enumerate(images):
            tmp = f"/content/tmp_img_{i}.png"
            img.save(tmp)
            zf.write(tmp, f"img_{i}.png")
            os.remove(tmp)
    print(f"Saved {len(images)} images to {zip_path}")

def load_synthetic_from_drive(label, gen):
    # Loads the previous generation's synthetic images
    zip_path = os.path.join(DRIVE_BASE, f"synthetic_{label}_gen{gen-1}.zip")
    all_images = []
    if os.path.exists(zip_path):
        with zipfile.ZipFile(zip_path, 'r') as zf:
            for name in zf.namelist():
                with zf.open(name) as f:
                    img = Image.open(f).convert("RGB")
                    img.load()
                    all_images.append(img)
        print(f"Loaded {len(all_images)} synthetic images from gen {gen-1}")
    else:
        print(f"No synthetic images found for gen {gen-1}")
    return all_images

def get_start_gen(label):
    # Returns the next generation to run based on what's already saved
    g = 0
    while os.path.exists(os.path.join(DRIVE_BASE, f"synthetic_{label}_gen{g}.zip")):
        g += 1
    return g

# Load existing FID history from Drive if it exists
fid_path = os.path.join(DRIVE_BASE, "fid_history.json")
if os.path.exists(fid_path):
    with open(fid_path, 'r') as f:
        fid_history = json.load(f)
    print("Loaded existing FID history:", fid_history)
else:
    fid_history = {label: [] for label in dataset_labels}
    print("Starting fresh FID history")

print(f"timing test {TOTAL_IMAGES_PER_GEN} images, {GENERATIONS} gen, device={DEVICE}")

for model_idx in range(number_of_models):
    label = dataset_labels[model_idx]
    human_ds = human_datasets[model_idx]

    start_gen = get_start_gen(label)

    print(f"model: {label}  ({len(human_ds)} human images) — resuming from gen {start_gen}")

    if start_gen >= GENERATIONS:
        print(f"Already complete for {label}, skipping.")
        continue

    for gen in range(start_gen, GENERATIONS):
        gen_start = time.time()
        print(f"Gen {gen} start")

        # Step 1: Load fresh model
        print("step 1: Loading fresh model")
        pipe = load_fresh_model()
        pipe.vae.enable_slicing()
        pipe.vae.enable_tiling()

        # Step 2: Build training loader
        print("step 2: Building training loader...")
        half = TOTAL_TRAIN_IMAGES // 2
        rng_mix = random.Random(SEED + gen)

        if gen == 0:
            # Gen 0: 100% human
            indices = rng_mix.sample(range(len(human_ds)), min(len(human_ds), TOTAL_TRAIN_IMAGES))
            subset = torch.utils.data.Subset(human_ds, indices)
            train_loader = torch.utils.data.DataLoader(
                subset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fp16
            )
        else:
            # Gen 1+: 50% human + 50% from previous gen only
            synthetic_pool = load_synthetic_from_drive(label, gen)
            human_indices  = rng_mix.sample(range(len(human_ds)), min(len(human_ds), half))
            human_subset   = torch.utils.data.Subset(human_ds, human_indices)
            syn_sample     = rng_mix.sample(synthetic_pool, min(len(synthetic_pool), half))
            syn_ds         = SyntheticImageDataset(syn_sample, transform=syn_transform)
            mixed_ds       = torch.utils.data.ConcatDataset([human_subset, syn_ds])
            train_loader   = torch.utils.data.DataLoader(
                mixed_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fp16
            )

        # Step 3: Fine-tune
        print("step 3: fine-tuning")
        pipe = finetune_lora(pipe, train_loader, epochs=1, lr=1e-4)

        torch.cuda.empty_cache()

        gc.collect()

        pipe.transformer.eval()
        pipe = pipe.to(DEVICE)

        # Step 4: Generate images
        print(f"step 4: generating")
        gen_images = []

        source_loader = torch.utils.data.DataLoader(
            human_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fp16
        )

        pipe.transformer.eval()
        with torch.no_grad():
            for batch_imgs, _ in source_loader:
                if len(gen_images) >= TOTAL_IMAGES_PER_GEN:
                    break

                prompt = rng.choice(CATEGORY_PROMPTS)
                _mean = torch.tensor([0.485, 0.456, 0.406], device=DEVICE, dtype=torch.float16).view(1,3,1,1)
                _std  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE, dtype=torch.float16).view(1,3,1,1)
                batch_imgs = batch_imgs.to(DEVICE, dtype=torch.float32)
                batch_imgs = (batch_imgs * _std.to(dtype=torch.float32) + _mean.to(dtype=torch.float32)).clamp(0, 1)
                with torch.autocast("cuda", dtype=torch.float16):
                  outputs = pipe(
                      prompt=prompt,
                      image=batch_imgs,
                      strength=STRENGTH,
                      num_inference_steps=NUM_INFERENCE_STEPS,
                      guidance_scale=GUIDANCE_SCALE,
                      num_images_per_prompt=1,
                  ).images
                gen_images.extend(outputs)
                print(f"    {len(gen_images)}/{TOTAL_IMAGES_PER_GEN} images", end="\r")

        print(f"Done generating {len(gen_images)} images")

        # Step 5: Save synthetic images to drive
        print("step 5: saving synthetic images to drive")
        save_synthetic_to_drive(gen_images, label, gen)

        # Step 6: Calculate FID
        print("step 6: Calculating FID...")
        test_loader_fid = torch.utils.data.DataLoader(
            test_ds, batch_size=BATCH_SIZE
        )
        fid_score = compute_fid(
            gen_images,
            test_loader_fid,
            sample_size_gen=len(gen_images),
            sample_size_real=len(gen_images),
        )
        fid_history[label].append(fid_score)

        # Save FID to drive after every generation
        with open(fid_path, 'w') as f:
            json.dump(fid_history, f, indent=4)
        print(f"FID saved to Drive")

        elapsed = time.time() - gen_start
        print(f"FID: {fid_score}, Time: {elapsed}s {elapsed/60} min")

        # Step 7: Cleanup
        del pipe, gen_images
        torch.cuda.empty_cache()
        vram_gb = torch.cuda.memory_allocated() / 1024**3

print("Done")
print("FID history:", fid_history)
# Out:
# Loaded existing FID history: {'HIGH': [211.08185069416936, 209.65115002018308]}
# ========================================
# timing test — 250 images | 10 gen | device=cuda
# ========================================
#
# ========================================
# MODEL: HIGH  (3428 human images) — resuming from gen 5
# ========================================
# Gen 5] Start
# step 1: Loading fresh model
#   [load_fresh_model] Loading SD3.5 quantized...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/517 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
#   [load_fresh_model] Done.
# step 2: Building training loader...
#   Loaded 250 synthetic images from gen 4
#   250 human + 250 synthetic = 500 total.
# step 3: Fine-tuning...
# trainable params: 681,984 || all params: 2,243,853,504 || trainable%: 0.0304
#   [LoRA] Epoch 1/1 — avg loss: 1.1188
# step 4: Generating 250 images...
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     1/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     2/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     3/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     4/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     5/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     6/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     7/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     8/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     9/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     10/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 10 255
#     11/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     12/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     13/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     14/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     15/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     16/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     17/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 20 255
#     18/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     19/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 4 255
#     20/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     21/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 235
#     22/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     23/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     24/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     25/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     26/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     27/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     28/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     29/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     30/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 14 255
#     31/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     32/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 251
#     33/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 6 255
#     34/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     35/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     36/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     37/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     38/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     39/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     40/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     41/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     42/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     43/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     44/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     45/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     46/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     47/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     48/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     49/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     50/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     51/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     52/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     53/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     54/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     55/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     56/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 1 255
#     57/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     58/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     59/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     60/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     61/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 254
#     62/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     63/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 4 255
#     64/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 24 255
#     65/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     66/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     67/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     68/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     69/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     70/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     71/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     72/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     73/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     74/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     75/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     76/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     77/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     78/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     79/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     80/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     81/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     82/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     83/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     84/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 3 255
#     85/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 5 255
#     86/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     87/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     88/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 4 255
#     89/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     90/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     91/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     92/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     93/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     94/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 23 255
#     95/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     96/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     97/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     98/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 16 255
#     99/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     100/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     101/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     102/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     103/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     104/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     105/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     106/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     107/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     108/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 18 255
#     109/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     110/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 7 255
#     111/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     112/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     113/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     114/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     115/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     116/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     117/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     118/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     119/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 12 255
#     120/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 3 255
#     121/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     122/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     123/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 21 255
#     124/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     125/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     126/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 20 255
#     127/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     128/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 14 255
#     129/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 45 255
#     130/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 5 255
#     131/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     132/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     133/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     134/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     135/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     136/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     137/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     138/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     139/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     140/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     141/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     142/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     143/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     144/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     145/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     146/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 4 255
#     147/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     148/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     149/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     150/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     151/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 248
#     152/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     153/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     154/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     155/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     156/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 29 255
#     157/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     158/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     159/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     160/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     161/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 1 255
#     162/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     163/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 245
#     164/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     165/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     166/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     167/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     168/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     169/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 212
#     170/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 7 255
#     171/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     172/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     173/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     174/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     175/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     176/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     177/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     178/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     179/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     180/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     181/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     182/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     183/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     184/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     185/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     186/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     187/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     188/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 4 255
#     189/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     190/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     191/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     192/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     193/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     194/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     195/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 18 255
#     196/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     197/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     198/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     199/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 19 253
#     200/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     201/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     202/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     203/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     204/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     205/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     206/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     207/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     208/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     209/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     210/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     211/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     212/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     213/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     214/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 8 255
#     215/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     216/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     217/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     218/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     219/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     220/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     221/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 254
#     222/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     223/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     224/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     225/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     226/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     227/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     228/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     229/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     230/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 6 255
#     231/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
# output type: <class 'PIL.Image.Image'>
# output size: (1024, 1024)
# output min/max: 0 255
#     232/250 images
#   0%|          | 0/7 [00:00<?, ?it/s]
